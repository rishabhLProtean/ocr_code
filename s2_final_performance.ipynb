# %%
import mysql.connector as con
from pdf2image import convert_from_path
import cv2
import numpy as np
import pytesseract
import re
from PIL import Image
from datetime import datetime
from time import process_time
import threading 
import time
from time import process_time

import config_pan


P1_time, P2_time,P3_time,P4_time,P5_time,P6_time,P7_time,P8_time,P9_time = 0,0,0,0,0,0,0,0,0

pytesseract.pytesseract.tesseract_cmd = r'F:\NOT_DONE_work\ocr\tesseract.exe'
poppler_path = r"C:/Program Files/poppler-22.04.0/Library/bin"
REMARK=""
host='localhost'
user='root'
passwd='nsdl@1234'
database='OCR_DB'
state_dict = {1 : "ANDAMAN AND NICOBAR ISLANDS", 2:"ANDHRA PRADESH", 3:"ARUNACHAL PRADESH", 4:"ASSAM", 5:"BIHAR",                                  
                    6:"CHANDIGARH", 7:"DADRA AND NAGAR HAVELI", 8:"DAMAN AND DIU" ,9:"DELHI", 10:"GOA", 11:"GUJARAT",
                  12:"HARYANA", 13:"HIMACHAL PRADESH", 14:"JAMMU AND KASHMIR", 15:"KARNATAKA" , 16:"KERALA", 17:"LAKHSWADEEP", 
                  18:"MADHYA PRADESH", 19:"MAHARASHTRA", 20:"MANIPUR", 21:"MEGHALAYA",22:"MIZORAM", 23:"NAGALAND" , 24:"ORISSA",
                  25:"PONDICHERRY",26:"PUNJAB", 27:"RAJASTHAN",28:"SIKKIM",29:"TAMILNADU",30:"TRIPURA" , 31:"UTTAR PRADESH" , 
                  32 : "WEST BENGAL", 33:"CHHATISHGARH",34:"UTTRAKHAND" , 35:"JHARKHAND" , 36:"TELANGANA", 
                  99:"ADDRESS OF DEFENCE EMPLOYEES", 88:"FOREIGN ADDRESS", 37:"LEH"}

# %%
def remove_spl(str_input):
    str_input = str(str_input)
    sp = str_input.split()
    sp_list=[]
    for i in range(0,len(sp)):
        sample_list=[]
        for i in sp[i]:
            if i.isalnum():
                sample_list.append(i)
        normal_string="".join(sample_list)
        sp_list.append(normal_string)
    sp =" ".join(sp_list)
    #print(sp)
    return sp

# %%
###function for nmatching words in columns[address,namess,DOB,ETC] ###

def Match_words(word, text_dict):
    name_lis = []
    brk=0
    NA = "NA"
    
    for m in range (0, len(word)):
        for n in range(0, len(word)):
        #print((str(word).lower())[j:len(word)-i])
            try:
                    
                if len((str(word).lower())[n:len(word)-m]) >= 4:
                    a = re.findall((str(word).lower())[n:len(word)-m],text_dict)
                    if len(a) != 0:
                        name_lis.append(a)
                        #print("a: ",a)
                        brk=1
                        break
                #print((str(word).lower())[len(word)-i:-1])
                    b = re.findall((str(word).lower())[m:len(word)-n],text_dict) 
                    if len(b) != 0:
                        name_lis.append(b)
                        #print("b: ",b)
                        brk=1
                        break
            except Exception as e:
                print(e)
                brk=1
                break
                        
        if brk:
            break
    print(name_lis, "NAME_LIS")
    #print("ok")
        
    return name_lis

# %%
def match_words_full(word_string_1, text_dict):

    word_string = word_string_1.split()
    word_string_match = []
    for words in word_string:
        word_len = re.search(str(words), text_dict)
        if word_len :
            word_string_match.append(words)### full word##
            percentage = 100
        else:
            half_word = Match_words(words, text_dict)   ### half word match #
                #print(type(address_word))
            if len(half_word) !=0:
                if len(half_word[0]) !=0:
                     word_string_match.append(half_word[0][0])
                     
                                
                    
                    #print(address_match)      
    add_join = " ".join(word_string_match)
    
    #print("IN:",word_string_1)
    #Print(type(word_string_1))
    #print("OUT_add:",add_join)
    print(add_join)
    percentage = (len(str(add_join))/ len(str(word_string_1)))*100
    #print(percentage)
    return [add_join, percentage]

# %%
def name_dob_match(row, first_index, mid_index, last_index, dob_index, text_dict):
    full_name = ''
    full_name_percentage = 0
    count = 0
    if row[last_index] != "nan":
        Ap_Last_Name = row[last_index]
        Ap_Last_Name = Ap_Last_Name.lower()
      
        Last_Name = match_words_full(Ap_Last_Name, text_dict)
        full_name = full_name + " "+ Last_Name[0]
        full_name_percentage = full_name_percentage +  Last_Name[1]
        count +=1
        
        
    else:
        Last_Name = ["No Input",0]
            
    
    
    if row[mid_index] != "nan":
        Ap_Mid_Name = row[mid_index]
        Ap_Mid_Name = Ap_Mid_Name.lower()
      
        Mid_Name = match_words_full(Ap_Mid_Name, text_dict)
        full_name = full_name + " "+ Mid_Name[0]
        full_name_percentage = full_name_percentage +  Mid_Name[1]
        count +=1
    else:
        Mid_Name = ["No Input",0]
                              
                              
                              
    
    if row[first_index] != "nan":
        Ap_First_Name = row[first_index]
        Ap_First_Name = Ap_First_Name.lower()
        First_Name = match_words_full(Ap_First_Name, text_dict)
        full_name = full_name + " "+ First_Name[0]
        full_name_percentage = full_name_percentage +  First_Name[1]
        count +=1            

    else:
        First_Name = ["No Input",0]
        
        
    if row[dob_index] != "nan":
        Ap_DOB = row[dob_index]
        #print(type(Ap_DOB))
        cleanString = ''.join(letter for letter in str(Ap_DOB) if letter.isalnum())  ###dob 1995-05-06 ==> 1995/05/06##
        dob_new = datetime.strptime(cleanString, "%Y%m%d").strftime('%d/%m/%Y')
        #print(dob_new)
        if re.search(str(dob_new), text_dict):  
            percentage = 100
            DOB = [dob_new, percentage]
        else:
            DOB= ["nan",0]
            

    else:
         DOB= ["No Input",0]
            
    if full_name_percentage !=0 and count != 0:
        full_name_percentage = full_name_percentage/count
    else:
        full_name_percentage = full_name_percentage
        
    Name_matched = [full_name,  full_name_percentage]
 

    return [ Name_matched , DOB]

# %%
def address_search_res(Pincode, Statecode,Res_add_1, Res_add_2,Res_add_3,Res_add_4,Res_add_5,text_dict):
    if Pincode !="nan":
        if re.search(str(Pincode), text_dict):
            res_pin = [str(Pincode), 100]
        else:
            res_pin = ['nan',0]
            
    else:
        res_pin = ["No Input",0]
        ##if pincode matched then go for remaining address ##
            
    res_statecode= Statecode
    print(res_statecode)
    state = str(state_dict[int(res_statecode)]).lower()
    print(state)
    state = state.split(' ')
    if Statecode !="nan":
        if re.search(state[0],text_dict):
            res_state =[str(state_dict[int(res_statecode)]),100]
        else:
            res_state =['nan',0]
            
    else:
        res_state =["No Input",0]
    
    address = str(Res_add_1)+ ' '+str(Res_add_2)+' '+str(Res_add_3)+ ' '+str(Res_add_4)+' '+ str(Res_add_5)
        #cleanString = ' '.join(letter for letter in address if letter.isalnum()) 
    address = address.lower()
    address_match_res = match_words_full(address, text_dict)
    return [address_match_res, res_pin, res_state]

# %%
##SEARCH ADHAAR DOC ##

def extract_and_collect(img):
    height = img.shape[0]
    width = img.shape[1]
    print(height,width)
    
    height_cutoff = height // 3
    
    p1 = img[ :height_cutoff, :]
    p2 = img[height_cutoff-50 : 2*(height_cutoff), :]
    p3 = img[2*(height_cutoff)-50 :height, :]

    lis = [p1,p2,p3]
    text = ""
    
    for j in lis:
        text += pytesseract.image_to_string(j,config='--psm 6')
        
    return text

# %%
def document_type_find(text, DOC_1, DOC_2, DOC_3, DOC_4, DOC_5,DOC_6):
    doc_words = ["UNIQUE", "Identification","AADHAAR", "ELECTION", "COMMISSION","REPUBLIC","PASSPORT", "DRIVE", "DRIVING","VEHICLE",  "INCOME", "TAX"]
    DOC_TYPE = ""
    text = remove_spl(text)
    for i in range(0, len(doc_words)):
        if i<3 and re.search(doc_words[i].lower(), text) :
            DOC_TYPE = "AADHAAR"
            DOC_1.update({ "DOC_TYPE": "AADHAAR",   "raw_text": text})
            break
        
        elif (3 <= i < 5) and re.search(doc_words[i].lower(), text):
            DOC_TYPE = "VOTER ID"
            DOC_2.update({ "DOC_TYPE":"VOTER ID" ,  "raw_text": text})
            break
        
        elif (5 <= i < 7) and re.search(doc_words[i].lower(), text):
            DOC_TYPE = "PASSPORT"
            DOC_3.update({"DOC_TYPE": "PASSPORT",   "raw_text": text})
            break
        
        elif (7 <= i < 10) and re.search(doc_words[i].lower(), text):
            DOC_TYPE = "DRIVING LICENSE"
            DOC_4.update({"DOC_TYPE": "DRIVING LICENSE",   "raw_text": text})
            break   
        
        elif (10 <= i < 12) and re.search(doc_words[i].lower(), text):
            DOC_TYPE = "PAN"
            DOC_5.update({"DOC_TYPE": "PAN",  "raw_text": text})
            break
            
        else:
            DOC_TYPE = "OTHER"
            DOC_6.update({"DOC_TYPE": "OTHER",  "raw_text": text})
            break
            
            
    return DOC_TYPE

# %%
def match_calculate(row, table,file_type,images, img_proc):
    ack_no = row[4]
    pdf_path = fr"{row[2]}/{ack_no}.pdf"
    doc1_percentage = 0
    doc2_percentage = 0
    doc3_percentage = 0
    doc4_percentage = 0
    full_pdf_percentage = 0
    REMARK = ""
    
    DOC_1= {"DOC_TYPE": "","Masked_Adhaar_No": '', "Ap_Full_Name":'',"Ap_DOB":'', "Res_Address":'', "Res_pin":'', "Res_State": '', "raw_text" : ""}
    DOC_2 = {"DOC_TYPE":"","Ap_Full_Name":'',"Ap_DOB":'', "Res_Address":'', "Res_pin":'', "Res_State":'', "raw_text" : ""}
    DOC_3 = {"DOC_TYPE":"","Ap_Full_Name":'',"Ap_DOB":'', "Res_Address":'', "Res_pin":'', "Res_State":'', "raw_text" : ""}
    DOC_4 = {"DOC_TYPE":"","Ap_Full_Name":'',"Ap_DOB":'', "Res_Address":'', "Res_pin":'', "Res_State":'', "raw_text" : ""}
    DOC_5 = {"DOC_TYPE":"", "raw_text" : ""}
    DOC_6 =  {"DOC_TYPE":"","Ap_Full_Name":'',"Ap_DOB":'', "Res_Address":'', "Res_pin":'', "Res_State":'', "raw_text" : "", "Masked_Adhaar_No": '',"PAN_no":''}
    
    DOC_1_PARAMETRS_percentage = {"DOC_TYPE": "", "Masked_Adhaar_No_Percent":0,"Ap_Full_Name_percentage":0,"Ap_DOB_percentage":0,"Res_Address_Percentage":0, "Res_pin_Percentage":0, "Res_State_Percentage": 0, "DOC_1_PERCENTAGE": 0}
    DOC_2_PARAMETRS_percentage = {"DOC_TYPE": "", "Ap_Full_Name_percentage":0,"Ap_DOB_percentage":'',"Res_Address_Percentage":0, "Res_pin_Percentage":0, "Res_State_Percentage": 0, "DOC_2_PERCENTAGE":0}
    DOC_3_PARAMETRS_percentage = {"DOC_TYPE": "", "Ap_Full_Name_percentage":0,"Ap_DOB_percentage":'',"Res_Address_Percentage":0, "Res_pin_Percentage":0, "Res_State_Percentage": 0, "DOC_3_PERCENTAGE":0}
    DOC_4_PARAMETRS_percentage = {"DOC_TYPE": "", "Ap_Full_Name_percentage":0,"Ap_DOB_percentage":'',"Res_Address_Percentage":0, "Res_pin_Percentage":0, "Res_State_Percentage": 0, "DOC_4_PERCENTAGE":0}
    DOC_5_PARAMETRS_percentage = {"DOC_TYPE": "" ,  "PAN_match_percentage":""}
    DOC_6_PARAMETRS_percentage = {"DOC_TYPE":"","Ap_Full_Name_percentage":'',"Ap_DOB_percentage":'', "Res_Address_Percentage":'', "Res_pin_Percentage":'', "Res_State_Percentage":'',  "Masked_Adhaar_No_Percent": '',"PAN_match_percentage":'', "DOC_6_PERCENTAGE":0}
  

    
    for i in range(2,len(images)):
        start_4 = time.time()
        opencvImage = cv2.cvtColor(np.array(images[i]), cv2.COLOR_RGB2BGR)
            
        image_text = extract_and_collect(opencvImage)
        end_4 = time.time()
        global P4_time
        P4_time = end_4 - start_4
            
            
        text_dict=image_text.replace("\n","")
        text_dict=text_dict.replace(" ","")
        text_dict = text_dict.lower()
        print("RAW text---->",text_dict)
        
        start_6 = time.time()
        document_type = document_type_find(text_dict, DOC_1, DOC_2, DOC_3, DOC_4, DOC_5,DOC_6)
        end_6 = time.time()
        global P6_time
        P6_time = end_6 - start_6
        
        start_7 = time.time()
        t1_initial_match = name_dob_match(row,7,8,6,17,text_dict)
        end_7 = time.time()
        global P7_time
        P7_time = end_7 - start_7
        
        if document_type == "AADHAAR":
            if row[33] !="nan":
                if re.search(((str(row[19])).replace("X","")), DOC_1["raw_text"]): ### masked adhar : 33###
                    masked_adhaar_matched = [str(row[19]) , 1]
                else:
                     masked_adhaar_matched = ['nan' , 0]

                start_9 = time.time()
                res_add = address_search_res(row[15], row[14], row[9],row[10],row[11],row[12],row[13],text_dict)
                doc1_percentage = (res_add[0][1]+ res_add[2][1]+res_add[1][1])/3
                end_9 = time.time()
                global P9_time
                P9_time = end_9 - start_9

                DOC_1.update({"Masked_Adhaar_No": masked_adhaar_matched[0], "Ap_Full_Name":t1_initial_match[0][0],"Ap_DOB":t1_initial_match[1][0], "Res_Address":res_add[0][0], "Res_pin":res_add[1][0], "Res_State": res_add[2][0]})
                DOC_1_PARAMETRS_percentage.update({"Masked_Adhaar_No_Percent": masked_adhaar_matched[1],"Ap_Full_Name_percentage":t1_initial_match[0][1],"Ap_DOB_percentage":t1_initial_match[1][1],"Res_Address_Percentage":res_add[0][1], "Res_pin_Percentage":res_add[1][1], "Res_State_Percentage": res_add[2][1], "DOC_1_PERCENTAGE":doc1_percentage})
                
                if doc1_percentage > config_pan.first_document_threshold:
                    REMARK = "AADHAAR DOC PERCENTAGE IS MORE THAN 70%" 
                    full_pdf_percentage = doc1_percentage
                    return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK, DOC_6, DOC_6_PARAMETRS_percentage]
             
      
        elif document_type == "VOTER ID":
                res_add = address_search_res(row[15], row[14], row[9],row[10],row[11],row[12],row[13],text_dict)
                doc2_percentage = (res_add[0][1]+ res_add[2][1]+res_add[1][1])/3

                DOC_2.update({"Ap_Full_Name":t1_initial_match[0][0],"Ap_DOB":t1_initial_match[1][0], "Res_Address":res_add[0][0], "Res_pin":res_add[1][0], "Res_State": res_add[2][0]})
                DOC_2_PARAMETRS_percentage.update({"Ap_Full_Name_percentage":t1_initial_match[0][1],"Ap_DOB_percentage":t1_initial_match[1][1],"Res_Address_Percentage":res_add[0][1], "Res_pin_Percentage":res_add[1][1], "Res_State_Percentage": res_add[2][1], "DOC_2_PERCENTAGE":doc2_percentage})

                if doc2_percentage > config_pan.first_document_threshold:
                    REMARK = "VOTER ID DOC PERCENTAGE IS MORE THAN 70%" 
                    full_pdf_percentage = doc2_percentage
                    return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK, DOC_6, DOC_6_PARAMETRS_percentage]
             
                
        
        elif document_type == "PASSPORT":
                res_add = address_search_res(row[15], row[14], row[9],row[10],row[11],row[12],row[13],text_dict)
                doc3_percentage = (res_add[0][1]+ res_add[2][1]+res_add[1][1])/3

                DOC_3.update({"Ap_Full_Name":t1_initial_match[0][0],"Ap_DOB":t1_initial_match[1][0], "Res_Address":res_add[0][0], "Res_pin":res_add[1][0], "Res_State": res_add[2][0]})
                DOC_3_PARAMETRS_percentage.update({"Ap_Full_Name_percentage":t1_initial_match[0][1],"Ap_DOB_percentage":t1_initial_match[1][1],"Res_Address_Percentage":res_add[0][1], "Res_pin_Percentage":res_add[1][1], "Res_State_Percentage": res_add[2][1], "DOC_3_PERCENTAGE":doc3_percentage})

                if doc3_percentage > config_pan.first_document_threshold:
                    REMARK = "PASSPORT DOC PERCENTAGE IS MORE THAN 70%"
                    full_pdf_percentage = doc3_percentage
                    return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK, DOC_6, DOC_6_PARAMETRS_percentage]
             
                
        elif document_type == "DRIVING LICENSE":
                res_add = address_search_res(row[15], row[14], row[9],row[10],row[11],row[12],row[13],text_dict)
                doc4_percentage = (res_add[0][1]+ res_add[2][1]+res_add[1][1])/3

                DOC_4.update({"Ap_Full_Name":t1_initial_match[0][0],"Ap_DOB":t1_initial_match[1][0], "Res_Address":res_add[0][0], "Res_pin":res_add[1][0], "Res_State": res_add[2][0]})
                DOC_4_PARAMETRS_percentage.update({"Ap_Full_Name_percentage":t1_initial_match[0][1],"Ap_DOB_percentage":t1_initial_match[1][1],"Res_Address_Percentage":res_add[0][1], "Res_pin_Percentage":res_add[1][1], "Res_State_Percentage": res_add[2][1], "DOC_4_PERCENTAGE":doc4_percentage})

                if doc4_percentage > config_pan.first_document_threshold:
                    REMARK = "DRIVING LICENSE DOC PERCENTAGE IS MORE THAN 70%" 
                    full_pdf_percentage = doc4_percentage
                    return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK, DOC_6, DOC_6_PARAMETRS_percentage]
             

                
        elif document_type == "PAN":   
            if row[18] !="nan" and file_type == 't1':
                if re.search(str(row[18]).lower(), text_dict):
                    PAN_no_match = match_words_full(str(row[18]), text_dict)
                    PAN_no = [PAN_no_match[0], 1]
                else:
                    PAN_no = ["Not Found",0]
                DOC_5.update({"PAN_no_match":PAN_no[0]})
                DOC_5_PARAMETRS_percentage.update({ "PAN_match_percentage":PAN_no[1]})
                
        elif document_type == "OTHER":
            if row[33] !="nan":
                if re.search(((str(row[19])).replace("X","")), DOC_1["raw_text"]): ### masked adhar : 33###
                        masked_adhaar_matched = [str(row[19]) , 1]
                else:
                    masked_adhaar_matched = ['nan' , 0]

                
            res_add = address_search_res(row[15], row[14], row[9],row[10],row[11],row[12],row[13],text_dict)
            doc6_percentage = (res_add[0][1]+ res_add[2][1]+res_add[1][1])/3
            
            if row[18] !="nan" and file_type == 't1':    
                if re.search(str(row[18]).lower(), text_dict):
                    PAN_no_match = match_words_full(str(row[18]), text_dict)
                    PAN_no = [PAN_no_match[0], 1]
                else:
                    PAN_no = ["Not Found",0]
                    
            DOC_6.update({"Masked_Adhaar_No": masked_adhaar_matched[0], "Ap_Full_Name":t1_initial_match[0][0],"Ap_DOB":t1_initial_match[1][0], "Res_Address":res_add[0][0], "Res_pin":res_add[1][0], "Res_State": res_add[2][0], "PAN_no_match":PAN_no[0]})
            DOC_6_PARAMETRS_percentage.update({"Masked_Adhaar_No_Percent": masked_adhaar_matched[1],"Ap_Full_Name_percentage":t1_initial_match[0][1],"Ap_DOB_percentage":t1_initial_match[1][1],"Res_Address_Percentage":res_add[0][1], "Res_pin_Percentage":res_add[1][1], "Res_State_Percentage": res_add[2][1], "DOC_6_PERCENTAGE":doc6_percentage})
                
            if doc6_percentage > config_pan.first_document_threshold:
                REMARK = "OTHER DOC PERCENTAGE IS MORE THAN 70%" 
                full_pdf_percentage = doc6_percentage
                return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK,  DOC_6, DOC_6_PARAMETRS_percentage]
             
            
            
        else:
            if i ==len(images):
                print("no doc DETECTED!!!")
                REMARK = "VALID ID PROOF NOT FOUND"
                full_pdf_percentage = 0
                return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK, DOC_6, DOC_6_PARAMETRS_percentage]

            
    full_pdf_percentage = max(float(DOC_1_PARAMETRS_percentage["DOC_1_PERCENTAGE"]), float(DOC_2_PARAMETRS_percentage["DOC_2_PERCENTAGE"]), float(DOC_3_PARAMETRS_percentage["DOC_3_PERCENTAGE"]), float(DOC_4_PARAMETRS_percentage["DOC_4_PERCENTAGE"]),float(DOC_6_PARAMETRS_percentage ["DOC_6_PERCENTAGE"]))
                      
    return [DOC_1, DOC_1_PARAMETRS_percentage, DOC_2, DOC_2_PARAMETRS_percentage, DOC_3, DOC_3_PARAMETRS_percentage, DOC_4, DOC_4_PARAMETRS_percentage,DOC_5, DOC_5_PARAMETRS_percentage, full_pdf_percentage,REMARK, DOC_6, DOC_6_PARAMETRS_percentage]

# %%
def ocrstart(row, table,file_type):
    ack_no = row[5]
    pdf_path = fr"{row[4]}/{ack_no}.pdf"
    
    try:
        start_1 = time.time()
        images = convert_from_path(pdf_path, 500 , poppler_path = poppler_path)
    
        end_1 = time.time()
        global P1_time
        P1_time = end_1 - start_1
    
    except Exception as e:
        # if ack no did not match P_PER_MATCHED = 0 ,  P_MATCG_STATUS = NO ACK  ,  P_PROC_FLAG =1  P_LUPD_DATE =now()
        connection = con.connect(host=host,user=user, passwd=passwd,database=database)
        cursor = connection.cursor()
        sql_update_qry = f"""UPDATE {table} SET O_PERCENT_PDF_MATCHED=0, O_MATCH_STATUS= 'NO PDF', O_PROC_FLAG=1,  O_LUPD_DATE =now(), O_REMARK = "NO PDF found"
                             WHERE  
                             P_BATCH_ID='{row[0]}' and P_ACK_NO='{ack_no}' """
        #print(sql_update_qry)
        cursor.execute(sql_update_qry)
        connection.commit()
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed",e)
        return 0
    
    start_2 = time.time()
    opencvImage = cv2.cvtColor(np.array(images[0]), cv2.COLOR_RGB2BGR)
    image_bw = cv2.cvtColor(opencvImage, cv2.COLOR_BGR2GRAY)
    
    #extract ack number from image
    crop_img = image_bw[50:250, 1700:2350]
    #cv2.imwrite(f"crop{ack_no}.jpg",crop_img)
    
    text_dict = pytesseract.image_to_string(crop_img)
    text_dict=text_dict.replace("\n","")
    text_dict=text_dict.replace(" ","")
    print(text_dict)
    
    #compare ack number
    ack_match = re.search(ack_no, text_dict)
    end_2 = time.time()
    global P2_time
    P2_time = end_2 - start_2
    
    if ack_match:
        documents_info = match_calculate(row, table,file_type,images, False)#True#
        #print(documents_info)
        #print(len(documents_info)," length...")
        
        final_percentage = documents_info[10]

        
        
        #if config_pan.crop_exec_thershold_min <= final_percentage < config_pan.crop_exec_thershold_max : #50#
        #    print(final_percentage,"--- less than 20")
        #    documents_info = match_calculate(row, table,file_type,images, False)
        #    #print(documents_info)
        #    final_percentage = documents_info[10]
        #    print(final_percentage,"--- after image crop and proc ")

       
        if final_percentage > config_pan.valid_invalid_threshold:
            results = "VALID"
        elif final_percentage<=20:
            results = "MANUALLY CHECK"
        else:
            results = "INVALID"
        
        start_8 = time.time()
        
        connection = con.connect(host=host,user=user, passwd=passwd,database=database) 
        cursor = connection.cursor()

        print("doc_info:---->\n ", documents_info)
        sql_update_qry = f"""UPDATE {table} SET   O_ADHAAR_NO_MATCHED = '{documents_info[1]["Masked_Adhaar_No_Percent"]}' , O_PAN_MATCHED = '{documents_info[9]["PAN_match_percentage"]}' , 
    O_DOC_1="{documents_info[0]["raw_text"]}", O_DOC_2="{documents_info[2]["raw_text"]}", O_DOC_3="{documents_info[4]["raw_text"]}", O_DOC_4="{documents_info[6]["raw_text"]}", O_DOC_5="{documents_info[8]["raw_text"]}",  O_DOC_6="{documents_info[12]["raw_text"]}",
        O_PERCENT_DOC1_MATCHED= '{documents_info[1]["DOC_1_PERCENTAGE"]}' , O_PERCENT_DOC2_MATCHED= '{documents_info[3]["DOC_2_PERCENTAGE"]}' , O_PERCENT_DOC3_MATCHED= '{documents_info[5]["DOC_3_PERCENTAGE"]}', O_PERCENT_DOC4_MATCHED= '{documents_info[7]["DOC_4_PERCENTAGE"]}',  O_PERCENT_DOC6_MATCHED= '{documents_info[13]["DOC_6_PERCENTAGE"]}',
        O_MATCH_STATUS = '{results}', O_PERCENT_PDF_MATCHED ="{final_percentage}",
        
        O_FULL_NAME_MATCHED_DOC1 = '{documents_info[0]["Ap_Full_Name"] + "," + str(documents_info[1]["Ap_Full_Name_percentage"])}', O_FULL_NAME_MATCHED_DOC2 = '{documents_info[2]["Ap_Full_Name"] + "," +  str(documents_info[3]["Ap_Full_Name_percentage"])}', O_FULL_NAME_MATCHED_DOC3 = '{documents_info[4]["Ap_Full_Name"] + "," + str(documents_info[5]["Ap_Full_Name_percentage"])}', O_FULL_NAME_MATCHED_DOC4 = '{documents_info[6]["Ap_Full_Name"]  + "," + str(documents_info[7]["Ap_Full_Name_percentage"])}',  O_FULL_NAME_MATCHED_DOC6 = '{documents_info[12]["Ap_Full_Name"] + "," + str(documents_info[13]["Ap_Full_Name_percentage"])}', 
    
        O_DOB_MATCHED_DOC1 = '{documents_info[0]["Ap_DOB"]  + "," + str(documents_info[1]["Ap_DOB_percentage"])}', O_DOB_MATCHED_DOC2 = '{documents_info[2]["Ap_DOB"] + "," + str(documents_info[3]["Ap_DOB_percentage"])}', O_DOB_MATCHED_DOC3 = '{documents_info[4]["Ap_DOB"]  + "," + str(documents_info[5]["Ap_DOB_percentage"])}', O_DOB_MATCHED_DOC4 = '{documents_info[6]["Ap_DOB"] + "," + str(documents_info[7]["Ap_DOB_percentage"])}',O_DOB_MATCHED_DOC6 = '{documents_info[12]["Ap_DOB"]  + "," + str(documents_info[13]["Ap_DOB_percentage"])}',
         
        O_ADDRESS_MATCHED_DOC1 = '{str(documents_info[0]["Res_Address"]) + "," +  str(documents_info[1]["Res_Address_Percentage"])}', O_ADDRESS_MATCHED_DOC2 = '{str(documents_info[2]["Res_Address"])  + "," +  str(documents_info[3]["Res_Address_Percentage"])}', O_ADDRESS_MATCHED_DOC3 = '{str(documents_info[4]["Res_Address"])  + "," +  str(documents_info[5]["Res_Address_Percentage"])}', O_ADDRESS_MATCHED_DOC4 = '{str(documents_info[6]["Res_Address"])  + "," + str(documents_info[7]["Res_Address_Percentage"])}',O_ADDRESS_MATCHED_DOC6 = '{str(documents_info[12]["Res_Address"]) + "," +  str(documents_info[13]["Res_Address_Percentage"])}', 
        O_STATE_MATCHED_DOC1 = '{str(documents_info[0]["Res_State"]) + "," +  str(documents_info[1]["Res_State_Percentage"])}', O_STATE_MATCHED_DOC2 = '{str(documents_info[2]["Res_State"]) + "," +  str(documents_info[3]["Res_State_Percentage"])}', O_STATE_MATCHED_DOC3 = '{str(documents_info[4]["Res_State"]) + "," +  str(documents_info[5]["Res_State_Percentage"])}', O_STATE_MATCHED_DOC4 = '{str(documents_info[6]["Res_State"]) + "," +  str(documents_info[7]["Res_State_Percentage"])}', O_STATE_MATCHED_DOC6 = '{str(documents_info[12]["Res_State"]) + "," +  str(documents_info[13]["Res_State_Percentage"])}',
        
        O_PINCODE_MATCHED_DOC1 = '{documents_info[0]["Res_pin"] + "," + str(documents_info[1]["Res_pin_Percentage"])}', O_PINCODE_MATCHED_DOC2 = '{documents_info[2]["Res_pin"] + "," +  str(documents_info[3]["Res_pin_Percentage"])}', O_PINCODE_MATCHED_DOC3 = '{documents_info[4]["Res_pin"] + "," +  str(documents_info[5]["Res_pin_Percentage"])}', O_PINCODE_MATCHED_DOC4 = '{documents_info[6]["Res_pin"] + "," + str(documents_info[7]["Res_pin_Percentage"])}', O_PINCODE_MATCHED_DOC6 = '{documents_info[12]["Res_pin"] + "," + str(documents_info[13]["Res_pin_Percentage"])}',
        
       
        O_REMARK='{documents_info[11]}', O_PROC_FLAG=1,  O_LUPD_DATE =now()
                             WHERE  
                             P_BATCH_ID='{row[1]}' and P_ACK_NO='{ack_no}' """
        print(sql_update_qry)
        cursor.execute(sql_update_qry)
        connection.commit()
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")
        end_8 = time.time()
        P8_time = end_8 - start_8

    else:
        # if ack no did not match P_PER_MATCHED = 0 ,  P_MATCG_STATUS = NO ACK  ,  P_PROC_FLAG =1  P_LUPD_DATE =now()
        connection = con.connect(host=host,user=user, passwd=passwd,database=database)
        cursor = connection.cursor()
        sql_update_qry = f"""UPDATE {table} SET O_PERCENT_PDF_MATCHED = 0, O_MATCH_STATUS= 'NO ACK', O_REMARK= 'NO ACK', O_PROC_FLAG=0,  O_LUPD_DATE =now()
                             WHERE  
                             P_BATCH_ID='{row[1]}' and P_ACK_NO='{ack_no}' """
        #print(sql_update_qry)
        cursor.execute(sql_update_qry)
        connection.commit()
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")

# %%
def start_process_3(u_id,file_type):
    try:
        connection = con.connect(host=host,user=user, passwd=passwd,database=database)
        table = "PAN_CUSTOMER_DATA1"
        sql_select_Query = f"select * from {table} where P_BATCH_ID = '{u_id}'"
        cursor = connection.cursor()
        cursor.execute(sql_select_Query)
        records = cursor.fetchall()
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")
            
        print("Total number of rows in table: ", cursor.rowcount)
        print("\nStarting Threading \n")
        
        #threading 
        if len(records)>4:
            var1 = len(records)//4
            #print(var1)
            p_record_t1 = records[:var1]
            #print(p_record_t1)
            p_record_t2 = records[var1:2*(var1)]
            #print(p_record_t2)
            p_record_t3 = records[2*(var1):3*(var1)]
            #print(p_record_t3)
            p_record_t4 = records[3*(var1):]
            #print(p_record_t4)
            
            thread1 = threading.Thread(target=threading_start,args=(p_record_t1,table,file_type,"Thread 1 Started"))
            thread2 = threading.Thread(target=threading_start,args=(p_record_t2,table,file_type,"Thread 2 Started"))
            thread3 = threading.Thread(target=threading_start,args=(p_record_t3,table,file_type,"Thread 3 Started"))
            thread4 = threading.Thread(target=threading_start,args=(p_record_t4,table,file_type,"Thread 4 Started"))
            
            thread1.start()
            thread2.start()
            thread3.start()
            thread4.start()
            
            thread1.join()
            thread2.join()
            thread3.join()
            thread4.join()
        else:
            for row in records:
                ocrstart(row,table,file_type)

    except Exception as e:
        print("Exception: ", e)
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")

# %%
def start_process_4(u_id,file_type):
    if True:
        connection = con.connect(host=host,user=user, passwd=passwd,database=database)
        table = "PAN_CUSTOMER_DATA1"
        sql_select_Query = f"select * from {table} where P_BATCH_ID = '{u_id}'"
        cursor = connection.cursor()
        cursor.execute(sql_select_Query)
        records = cursor.fetchall()
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection is closed")
            
        print("Total number of rows in table: ", cursor.rowcount)
        print("\nStarting Threading \n")
        
        #threading 
        if len(records)>4:
            var1 = len(records)//4
            #print(var1)
            p_record_t1 = records[:var1]
            #print(p_record_t1)
            p_record_t2 = records[var1:2*(var1)]
            #print(p_record_t2)
            p_record_t3 = records[2*(var1):3*(var1)]
            #print(p_record_t3)
            p_record_t4 = records[3*(var1):]
            #print(p_record_t4)
            
            thread1 = threading.Thread(target=threading_start,args=(p_record_t1,table,file_type,"Thread 1 Started"))
            thread2 = threading.Thread(target=threading_start,args=(p_record_t2,table,file_type,"Thread 2 Started"))
            thread3 = threading.Thread(target=threading_start,args=(p_record_t3,table,file_type,"Thread 3 Started"))
            thread4 = threading.Thread(target=threading_start,args=(p_record_t4,table,file_type,"Thread 4 Started"))
            
            thread1.start()
            thread2.start()
            thread3.start()
            thread4.start()
            
            thread1.join()
            thread2.join()
            thread3.join()
            thread4.join()
        else:
            threading_start(records,table,file_type,"no Threading!!!")
            #for row in records:
             #   ocrstart(row,table,file_type)

    else:
        print("Exception: ")

# %%
def thread_name_status_update(p_record,msg):
    connection = con.connect(host=host,user=user, passwd=passwd,database=database)
    table = "PAN_CUSTOMER_DATA1"
    cursor = connection.cursor()
    p_record = list(p_record)
    print(p_record)
    for i in range(0, len(p_record)):
        
        sql_update_Query = f"""UPDATE {table} SET THREADING_NAME = '{msg}'
                            WHERE  P_ACK_NO='{i[5]}' """
        
        #print(sql_update_qry)
        cursor.execute(sql_update_qry)
        
    connection.commit()
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed")

# %%
"""
def threading_start(p_record,table,file_type,msg):
    print(msg)
    thread_name_status_update(p_record,msg)
    for row in p_record:
        ocrstart(row,table,file_type)
"""
# Out:
# '\ndef threading_start(p_record,table,file_type,msg):\n    print(msg)\n    thread_name_status_update(p_record,msg)\n    for row in p_record:\n        ocrstart(row,table,file_type)\n'

# %%
def threading_start(p_record,table,file_type,msg):
    for row in p_record:
        ocrstart(row,table,file_type)
        connection = con.connect(host=host,user=user, passwd=passwd,database=database)
        cursor = connection.cursor()
        sql_insert_qry = f"""INSERT INTO PROCESS_PERFORMANCE_CHK VALUES('{row[5]}','{P1_time}','{P2_time}','{P3_time}','{P4_time}','{P5_time}','{P6_time}','{P7_time}',
        '{P8_time}','{P9_time}') """
        #print(sql_update_qry)
        cursor.execute(sql_insert_qry)
        connection.commit()
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("MySQL connection_performance is closed")

# %%
import time
from time import process_time
start = time.time() 
#start_process_4('f2522636586449ad931928b31e244dab','t1') 
start_process_4('ca7756c2c9384a968db59faf421f1f2e','t1')


#start_process_4('f12e97dfab5246a2a7fd1b8d17d68db9','t2') 

#F:Projects WorkingPAN_OCR_Documentdata
end = time.time() 
time1 = end - start
print(time1) #F:Projects WorkingPAN_OCR_Documentdata
# Out:
# MySQL connection is closed
# Total number of rows in table:  98
#
# Starting Threading
#
# -881037243583652
# 5848 4132
# -881037243588121
# -881037243558651
# 5848 4132
# 5848 4132
# -881037243595331
# 5848 4132
# RAW text----> seee~governmentofindiastas!pea‘uniqueidenti‘|cmalmins/oaaasee,tia14aeragetalmin!awerict,atsgellelale,aai81/dob:04/06/1997!eaewaal+212402ss|ges/male|{8address:'}25/0maqboolahamad,mage12a|1skhundmeer,postkatrauli,phulpmm(an|>uttarpradesh-212402gae.ooooa0::oo831980580364:831!fatitsitet.,=ouecic:aisa7sce—<]help
# almin
# 31
# uttar pradesh
# [] NAME_LIS
# [['phulp']] NAME_LIS
# [['laha']] NAME_LIS
# 14 khundmeer phulp post katrauli laha
# doc_info:---->
#   [{'DOC_TYPE': 'AADHAAR', 'Masked_Adhaar_No': 'XXXXXXXX0364', 'Ap_Full_Name': ' almin', 'Ap_DOB': '04/06/1997', 'Res_Address': '14 khundmeer phulp post katrauli laha', 'Res_pin': '212402', 'Res_State': 'UTTAR PRADESH', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 1, 'Ap_Full_Name_percentage': 100.0, 'Ap_DOB_percentage': 100, 'Res_Address_Percentage': 74.0, 'Res_pin_Percentage': 100, 'Res_State_Percentage': 100, 'DOC_1_PERCENTAGE': 91.33333333333333}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 91.33333333333333, 'AADHAAR DOC PERCENTAGE IS MORE THAN 70%', {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': '', 'Masked_Adhaar_No': '', 'PAN_no': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': '', 'Ap_DOB_percentage': '', 'Res_Address_Percentage': '', 'Res_pin_Percentage': '', 'Res_State_Percentage': '', 'Masked_Adhaar_No_Percent': '', 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '1' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="",
#         O_PERCENT_DOC1_MATCHED= '91.33333333333333' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0',
#         O_MATCH_STATUS = 'VALID', O_PERCENT_PDF_MATCHED ="91.33333333333333",
#
#         O_FULL_NAME_MATCHED_DOC1 = ' almin,100.0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ',',
#
#         O_DOB_MATCHED_DOC1 = '04/06/1997,100', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = ',',
#
#         O_ADDRESS_MATCHED_DOC1 = '14 khundmeer phulp post katrauli laha,74.0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',',
#         O_STATE_MATCHED_DOC1 = 'UTTAR PRADESH,100', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = ',',
#
#         O_PINCODE_MATCHED_DOC1 = '212402,100', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = ',',
#
#
#         O_REMARK='AADHAAR DOC PERCENTAGE IS MORE THAN 70%', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243583652'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> :=a-tr!peril=rajmumer|eraapyydor:10/08/1999:4ae:cgi|i|\237344740727||aaorrerre,ae3dae—-oe-=——s=—x;i:=aaai.==)see—i”a—sp=:seei:isiplihat=-—i*lmenaale--—|rwy.7r-==.:|-i"iiv,“/>‘=—ro;4a)_“ah;cy,,|:.|\*‘a=:a=‘,=“=%—_e/ib2r;aalee_aa©;o‘erzz==77ief1=,iiai7=lom=—*=4'a:1a:fi1—uabsheefiir).iii-“a;a:=—ey=a_shea.iaai-:;ieaiyae
# [] NAME_LIS
#
# 27
# rajasthan
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# 0
# 5848 4132
# -881037243583803
# 5848 4132
# RAW text----> eafonvit«zo-\\"dks+sam.wrewerehatuttp66heigs|govemmentofindia||epeydiag(qos)phshow|ulaleleemlelciplililercltlelematelialejiisaceimge|(camsara)hory/enrollmentno.:2052/60036/06110tshaikmagboo!bashaseamen.ghpeersc/o:shaikibrahim,|1-39,gangapuram,chinnathippasamudram,madanapalle,vtc:chinnathippasamudram,po:chinnatippasamudram,subdistrict:madanapalle,district:chittoor,®state:andhrapradesh,pincode:517319.ismobile:9949086076detcraepanreseatunis=(odlnutnniiminiimnn,raeemeiiaiemoreteekf794654649f2eeedayeaseeoesox02/youraadhaarno.:qaqhe[a222q9maqaiitvo1loyviijz09aeseyd,dp06022)pottschrdopetecbeoatpascewume0nea66vasinfbrosbepego.rw.|--4“governmentofindias-——ard||_ass26odora|ofa|shaikmagboo!basha—})cage86/dob:2004/1989=:ficape/maleof|"io)aeio313616339283areserd,ds?06022)
# shaik
# [['magboo', 'magboo']] NAME_LIS
# magboo basha
# 2
# andhra pradesh
# [] NAME_LIS
# gangapuram madanapalle chinnathippasamudram chittoor
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 97.61904761904763, 'OTHER DOC PERCENTAGE IS MORE THAN 70%', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': ' shaik magboo basha', 'Ap_DOB': 'nan', 'Res_Address': 'gangapuram madanapalle chinnathippasamudram chittoor', 'Res_pin': '517319', 'Res_State': 'ANDHRA PRADESH', 'raw_text': '...', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'Not Found'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 96.15384615384616, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 92.85714285714286, 'Res_pin_Percentage': 100, 'Res_State_Percentage': 100, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 97.61904761904763}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="...",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '97.61904761904763',
#         O_MATCH_STATUS = 'VALID', O_PERCENT_PDF_MATCHED ="97.61904761904763",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ' shaik magboo basha,96.15384615384616',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = 'nan,0',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = 'gangapuram madanapalle chinnathippasamudram chittoor,92.85714285714286',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'ANDHRA PRADESH,100',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = '517319,100',
#
#
#         O_REMARK='OTHER DOC PERCENTAGE IS MORE THAN 70%', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243588121'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> =~y|“ann.|———an.artweangwtare‘|gemmabaileaadhaarhaitdgathi<;clo\claalpnicisimelmialelts!s(|seeearorwar8,arrrecrarset);gearsafleae|sdafafasegecletbfavr‘|maewegeagiewiregrragovabiolalreler-mlel-ialiieciiielama\eligesamelmislelt-)statessaea/enrolmentno:92898/01012/00201informationarar34/enrolmentno.:2828/01012/00201'informationto||@aadhaarisaproofofidentity,notofcitizenship.onebesa‘|verifyidentityusingsecureqrcode/offlinexml/onlinew/ojagdishkashyapauthentication.schahtaraepiend‘|@thisiselectronicallygeneratedletter.devinagar(115)sirmaurhimachalpradesh-173025'8894841857';@omeeaae4a|©stirfegonberegatsarai@lgatsrmfatt&|vetted@sme4alargeraxaiesatwwssc<ahesetewiihee=stegh)wesiehawewa,maadhaarapp==see|&uregreainaoo‘reehaesb)de'sahacseaciena|_eaebereee®aadhaarisvalidthroughoutthecountry.seerghcaee||ecaelnihesaeseekae=aadhaarhelpsyouavailvariousgovernmentbeyensandnon-governmentserviceseasily.;;=keepyourmobilenumber&email|dupdatedattahtthath/youraadhaarno.:inaadhaar.543113840027®carryaadhaarinyoursmartphone—usevid:9161952655418189?maadhaarapp.setarene,ayveutbssesossssseseru88s5h205062255cossetcebehosanesesteasproo0655sssssssssnssss20005800025552504s06000eetax.|bdcoredfattergearwriterzzbesigxenmeitommaamer——rere)‘uniqueidentificationauthorityofindia_ss.‘|tmt:pos)ete‘oomaarea,et.2o¢ardah.e,cettecetoessea—sséronittapainulyse,natore,rea,seiden1gorono&wifaf&/dob:08/05/19841omenset-373025eriyteeae3_-aigen/female|resativhataaaetee*‘its¥:fegansee+fano.9bepoantasahib,devinagarshayaeorere,a'(115)sirmaur,saelitetea:primepraeah«179005riesmmcr42betaeeebytesee,syee)543113840027543113840027d:9161952655418189yvid:9161952655418185aratrere,adgearg1957|efhepeuiasi.govin|gpwww.uidsi.gev.in
# painuly
# [['ronit']] NAME_LIS
# ronit
# 13
# himachal pradesh
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# h no no 9 devi nagar sahib sirmaur
# doc_info:---->
#   [{'DOC_TYPE': 'AADHAAR', 'Masked_Adhaar_No': 'XXXXXXXX0027', 'Ap_Full_Name': ' painuly ronit', 'Ap_DOB': '08/05/1984', 'Res_Address': 'h no no 9 devi nagar sahib sirmaur', 'Res_pin': '173025', 'Res_State': 'HIMACHAL PRADESH', 'raw_text': '...é'}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 1, 'Ap_Full_Name_percentage': 91.66666666666667, 'Ap_DOB_percentage': 100, 'Res_Address_Percentage': 59.64912280701754, 'Res_pin_Percentage': 100, 'Res_State_Percentage': 100, 'DOC_1_PERCENTAGE': 86.54970760233918}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 86.54970760233918, 'AADHAAR DOC PERCENTAGE IS MORE THAN 70%', {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': '', 'Masked_Adhaar_No': '', 'PAN_no': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': '', 'Ap_DOB_percentage': '', 'Res_Address_Percentage': '', 'Res_pin_Percentage': '', 'Res_State_Percentage': '', 'Masked_Adhaar_No_Percent': '', 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '1' , O_PAN_MATCHED = '' ,
#     O_DOC_1="...é", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="",
#         O_PERCENT_DOC1_MATCHED= '86.54970760233918' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0',
#         O_MATCH_STATUS = 'VALID', O_PERCENT_PDF_MATCHED ="86.54970760233918",
#
#         O_FULL_NAME_MATCHED_DOC1 = ' painuly ronit,91.66666666666667', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ',',
#
#         O_DOB_MATCHED_DOC1 = '08/05/1984,100', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = ',',
#
#         O_ADDRESS_MATCHED_DOC1 = 'h no no 9 devi nagar sahib sirmaur,59.64912280701754', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',',
#         O_STATE_MATCHED_DOC1 = 'HIMACHAL PRADESH,100', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = ',',
#
#         O_PINCODE_MATCHED_DOC1 = '173025,100', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = ',',
#
#
#         O_REMARK='AADHAAR DOC PERCENTAGE IS MORE THAN 70%', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243558651'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> —————————ebopederiesparett=ebh.=|&(umguenuentreanomaltoryofindia|svaan‘i|=.|ye:rte,fewaeseawis’,«er,bgurrrsrnsétobentosaca|©ieneaaeae|\+air||"5.237344740727aaip:913762877817634:=.——ii.ifa)help@vicioi.oow.i|eras.lienigecebore;"|@iesecr|tegseleceteteree_“4lilies=——eee7;+|_—.aj,a.:=—=7:__as—.osf.'*rr->sig=.za;s‘2+wihaee“an:1)"|"_a|.|en>eeeez4,—be:uyi:ft.i-|75*|i-aa-a;_-_-...!ami-ias:=-ilm7=aaca-=itali!=!iema\i._uy=aae-i==aertail!a’-..wei"7“7=
# [] NAME_LIS
#
# 27
# rajasthan
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# 0
# 5848 4132
# -881037243588154
# 5848 4132
# -881037243576604
# 5848 4132
# RAW text----> sec~-.wwgpooe*pyv\\\4bytss"zannyisagr»|:ps-7s.rersesatuttneearlareaadhaarhidalar!fey(=)saleat=)a)@e)miarelte!malgat|seresiteatargaataieariearcararatelre!.eewitlatassblogta(|a2seteetiaeoidaaoeeetotat.uniqueidentificationauthorityofindia!afeetspare:/enrolmentno.:2821/35042/00131informationto||@aadhaarisaproofofidentity,notofcitizenship.aibpadoisgdpoo!ofpotiily,tolotcillariorilpy.aecdacaccerome'|@verifyidentityusingsecureqrcode/offlinexml/onlinec/o:sagarpawarauthentication.srno.106,bharatnagar,aopineiby!@thisiselectronicallygeneratedletter.punemaharashtra=411006|446657122!msunaedayaie|msuramegrenflaysearsift]arorhaay|walesusefedatasigevarfae_-_esaefasefazsithsetearyaureasnaaaeeese,!aiebaspeeorsachenee,!mselshehraaearuwl-maadhaarappsrrvethacontencceenaaogelo|baieaetspe@aadhaarisvalidthroughoutthecountry.ieneaera|eehebeaay|=aadhaarhelpsyouavailvariousgovernmentseercaeee,||:|tehfatshoandnon-governmentserviceseasily.leeineraeeesekele,i,..=keepyourmobilenumber&emailidupdatedasstatshats/youraadhaarno.:inaadhaar.321235925728@carryaadhaarinyoursmartphone—usevid:910817978273835/maaadhaaranoparasegtpbeenamoneckmonty,mmaaagnaarapp.ats!at,atshees!se,,,,,——————————————————————————eeideeeeee.saraarr==bdgovernmentofindia==aw‘uniqueidentificationauthorityofindiata.ersekissem::neeeeaeaeoeerakalskar|[asag:ppecatr,a7106,ettfre,pttee,epeeeeeaisaayanita/dob:18/06/1998|jsmerete:-411006eeeee3sftfemale||baddress:seeeeea'}oc/o:sagarpawar,srno.106,bharatnagar,,(ayiateangaseneeer|2punecity,pune.ietseeeawaa|||=maharashtra-411006peisercoaeaaeataioeerene=beaidantorefiabeseceierckaesi=seeeet,aea;foesoataceratesifelebnce321235925/28|321235925/28wid|siu81/9/62-aid91051/97b273barefsven,sagesstress:4047|help@uldsigovin|@fbwww.uldel.govin
# pawar
# sagar
# [] NAME_LIS
#
# 19
# maharashtra
# [] NAME_LIS
# [['ment', 'ment', 'ment', 'ment']] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# sr no 106 bharat nagar ment pune
# doc_info:---->
#   [{'DOC_TYPE': 'AADHAAR', 'Masked_Adhaar_No': 'XXXXXXXX5728', 'Ap_Full_Name': ' pawar sagar ', 'Ap_DOB': '18/06/1998', 'Res_Address': 'sr no 106 bharat nagar ment pune', 'Res_pin': '411006', 'Res_State': 'MAHARASHTRA', 'raw_text': '...'}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 1, 'Ap_Full_Name_percentage': 66.66666666666667, 'Ap_DOB_percentage': 100, 'Res_Address_Percentage': 54.23728813559322, 'Res_pin_Percentage': 100, 'Res_State_Percentage': 100, 'DOC_1_PERCENTAGE': 84.7457627118644}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 84.7457627118644, 'AADHAAR DOC PERCENTAGE IS MORE THAN 70%', {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': '', 'Masked_Adhaar_No': '', 'PAN_no': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': '', 'Ap_DOB_percentage': '', 'Res_Address_Percentage': '', 'Res_pin_Percentage': '', 'Res_State_Percentage': '', 'Masked_Adhaar_No_Percent': '', 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '1' , O_PAN_MATCHED = '' ,
#     O_DOC_1="...", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="",
#         O_PERCENT_DOC1_MATCHED= '84.7457627118644' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0',
#         O_MATCH_STATUS = 'VALID', O_PERCENT_PDF_MATCHED ="84.7457627118644",
#
#         O_FULL_NAME_MATCHED_DOC1 = ' pawar sagar ,66.66666666666667', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ',',
#
#         O_DOB_MATCHED_DOC1 = '18/06/1998,100', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = ',',
#
#         O_ADDRESS_MATCHED_DOC1 = 'sr no 106 bharat nagar ment pune,54.23728813559322', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',',
#         O_STATE_MATCHED_DOC1 = 'MAHARASHTRA,100', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = ',',
#
#         O_PINCODE_MATCHED_DOC1 = '411006,100', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = ',',
#
#
#         O_REMARK='AADHAAR DOC PERCENTAGE IS MORE THAN 70%', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243583803'
# MySQL connection is closed
# MySQL connection_performance is closed
# -881037243584061
# 5848 4132
# RAW text----> incometaxdepartmentgovt.ofindiavetsaatavitpermanentaccountnumberftjpr4678qa4/namerajkumarolfats/dateofbirth10/08/1999fer|gendermaleswfffli\aabiaaivicaamenebeet/aadhaarnumber000000727-i_-[a]he:eedaanesrieel:[a]|‘yaeciasinnsignaturenotverified|7anenatget-bidetthreateae_é.erentlforathiie27ediedigitalf¥'sibyebgeatepeariesdsincomeaaxasvine,oyaedepartment1aaeeeeeheal©permanentaccountnumber(pan)isatendigitalphanumericnumberallottedbytheincome-taxdepartmentforcompliancetotheprovisionsofincome-taxactandrulesincludingfilingofincome-taxreturn,paymentoftaxesetc..wgcatut(wa)whtaagotmenigtvet&uhawaaxalaaagwaagtedgxsitimakagarreawh@foefaatataquestecaleheeqstafedfarurez|°oquotingofpanismandatoryforseveraltransactionsspecifiedunderincome-taxact,1961(referrule114bofincome-taxrules,1962)arraysifafaa,1961&dedfessoscesgfoewisceawen(34)ohseersalfa&(samefray,1962gfray11447,atwayci)©possessionoruseofmorethanonepanisagainstthelawandmayattractpenaltyofrs.10,000/-whuatiereceagea(ga)watavighel,ga&fase&besufey10,000washiasestmautgadze!othepancardenclosedcontainsqrcodewhichisreadablebyaspecificmobileapp.artwwos4wetwroswaa&€wtwwfasewwsewasawwwariucar|sirispeeetseeeeneeeaaaaaaa'!|se)3ielepeferatroraduhi=>,|!iisincometaxdepartmentgovt.ofindia=wtots@at/iwwpoaadwe/citer:!at|-wraepea“waefreee(taf)-1,t4afeqer‘iipermanentaccountnumber_odlafte,aaaaa,baer—3,azrref,;‘it|!ftjpr4678q-anferarare=201010,baeweet!|ro,oeasdaantshleeteedifthiscardislost/someone’slostcardisfound.xt#/;name..spomegrot:pleaseinform/returnto:.|rajkumarseee_jointdirector(systems)-1,panmodulet||as9thfloor,aayakarbhawan,sector—3,vaishali,t|rorriieiioneersinhereaesghaziabad-201010,uttarpradesh|10/08/1999chevihheroereees:tel-no~0420-2:0120-2770078::wrakh,atssadpeace2aferaealmail-id:peaki||sbeerete!/signaturenen.inlraeneeteeresnepestod|:tra.ansmeeerste,yeeegeieeedockwuetconeisowesaspeecaesonebacabaseweweununbelelacesublobeunlsnewweunsduowneaeceobews
# rajkumar
# 27
# rajasthan
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# 0
# [['ftjpr4678q', 'ftjpr4678q']] NAME_LIS
# ftjpr4678q
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 0.7407407407407408, '', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': ' rajkumar', 'Ap_DOB': '10/08/1999', 'Res_Address': '0', 'Res_pin': 'nan', 'Res_State': 'nan', 'raw_text': 'incometaxdepartmentgovtofindiavetsaatavitpermanentaccountnumberftjpr4678qa4namerajkumarolfatsdateofbirth10081999fergendermaleswfffliaabiaaivicaamenebeetaadhaarnumber000000727iaheeedaanesrieelayaeciasinnsignaturenotverified7anenatgetbidetthreateaeé...', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'ftjpr4678q'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 100.0, 'Ap_DOB_percentage': 100, 'Res_Address_Percentage': 2.2222222222222223, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0.7407407407407408}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="incometaxdepartmentgovtofindiavetsaatavitpermanentaccountnumberftjpr4678qa4namerajkumarolfatsdateofbirth10081999fergendermaleswfffliaabiaaivicaamenebeetaadhaarnumber000000727iaheeedaanesrieelayaeciasinnsignaturenotverified7anenatgetbidetthreateaeé...",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0.7407407407407408',
#         O_MATCH_STATUS = 'MANUALLY CHECK', O_PERCENT_PDF_MATCHED ="0.7407407407407408",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ' rajkumar,100.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = '10/08/1999,100',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = '0,2.2222222222222223',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'nan,0',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = 'nan,0',
#
#
#         O_REMARK='', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243595331'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> isga.y'aa»)),weeweertghtutshaltdauch!(cre)\{-)salanl=iaimelmialeli=!,aadafarezieofl‘|gulallelel-mlel-ialtiiver-liielamalelialesiame)minleli>aleufthatsh:/enrolmentno.:2006/11105/15988§to‘|«s$temgeesazrefen‘|.8reshmaislamvaraliyaawotticefaotcarttvwcaracalya'=c/oislamvaraliya6a/103alhusainbuildingstationroad‘|@=opprailwaystationmominnagar=mumbai;5jogeshwariwestmumbaisuburbanmaharashtra-4001029821633128'5'=®'cosigna!venfied,sweapofpasegasahashedtenageeaeftpeeeee:||-fsgielen|:8aiens=||:binkssaarreyeotbareroatloaseesagngeae2aephegnertladcg|dressyeeoe.:ngsrecitele‘cayehopesattataronmeadeee3pastad4ek:bsneitenaesaeak[s)sschssanetaeahetgaatulhath/youraadhaarno.:vid:9154277556018810!ats!ftv,atsilhiroe!bindeeeee‘tas.||©=_governmentofindiaomaredom92257sayaxtettay;cisreshmaislamvaraliyazts:ahaka/dob:02/10/19845|3saftafemales:2dave,/=bts=tsis8itsts°ym685109106393:vid:9154277556018810yats?377871,atst’3171sscannedwithcamscanner
# varaliya
# islam
# reshma
# 19
# maharashtra
# [] NAME_LIS
# [] NAME_LIS
# al husain momin nagar station road jogeshwari west opp railway station mumbai
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 96.16858237547893, 'OTHER DOC PERCENTAGE IS MORE THAN 70%', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': ' varaliya islam reshma', 'Ap_DOB': '02/10/1984', 'Res_Address': 'al husain momin nagar station road jogeshwari west opp railway station mumbai', 'Res_pin': '400102', 'Res_State': 'MAHARASHTRA', 'raw_text': '...', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'Not Found'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 100.0, 'Ap_DOB_percentage': 100, 'Res_Address_Percentage': 88.50574712643679, 'Res_pin_Percentage': 100, 'Res_State_Percentage': 100, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 96.16858237547893}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="...",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '96.16858237547893',
#         O_MATCH_STATUS = 'VALID', O_PERCENT_PDF_MATCHED ="96.16858237547893",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ' varaliya islam reshma,100.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = '02/10/1984,100',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = 'al husain momin nagar station road jogeshwari west opp railway station mumbai,88.50574712643679',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'MAHARASHTRA,100',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = '400102,100',
#
#
#         O_REMARK='OTHER DOC PERCENTAGE IS MORE THAN 70%', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243576604'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> 13a.he:e(a497174371432‘4nrmdbirsc8488740115‘bcpaaeeeeacoreaceomtountrau497174371432.4]wd:9722046488740719le?|anotpemnamgovin|gbwewudagoum_|
# [] NAME_LIS
#
# [] NAME_LIS
#
# 31
# uttar pradesh
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
#
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 0.0, '', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': '  ', 'Ap_DOB': 'nan', 'Res_Address': '', 'Res_pin': 'nan', 'Res_State': 'nan', 'raw_text': '13aheea4971743714324nrmdbirsc8488740115bcpaaeeeeacoreaceomtountrau4971743714324wd9722046488740719leanotpemnamgovingbwewudagoum', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'Not Found'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0.0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0.0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0.0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="13aheea4971743714324nrmdbirsc8488740115bcpaaeeeeacoreaceomtountrau4971743714324wd9722046488740719leanotpemnamgovingbwewudagoum",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0.0',
#         O_MATCH_STATUS = 'MANUALLY CHECK', O_PERCENT_PDF_MATCHED ="0.0",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = '  ,0.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = 'nan,0',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',0.0',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'nan,0',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = 'nan,0',
#
#
#         O_REMARK='', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243584061'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> eee\‘to\\:pd“iten;weaeertut|aeeaadhaarophhwsbtsfimmisw|pe‘croy'{=)eelantsiayee)mialeire.|:oatiatted‘|@mso)seolwntsepnhsnensnsigygqupmwsssisdov.;smueeitsosuwetugshsimlwrmgengseflunpsacydopssonisolwineblenrsworsssoloolit,‘|&ogiqedrralésoswi(_eappedgsurmseouce+yd-—sneos—<waesn-atbetebearse;os”pi—77s|okaglelrolelomlel-ialttiler-itlepmatelia(eleia'melmlaleit=)4aula,tausgau_@«rer/enrolmentno.:0000/00504/23165:informationto‘|®aachaarisaproofofidentity,notofcitizenship.aebsgtettp,a2.;:anuthigsharangaral1%verifyidentityusingsecureqrcode/offlinexml/onlined/orangaraj;authentication.c-36aly‘iy‘aeratinea!thisiselectronicallygeneratedletter.|block-26,neyvelitownshipkurinjipaditaluk'|neyvelicuddaloretamilnadu-607803b4s)bieyupgdascdguuiqumgw9750230618audcagysyswmsiesronceemousenmachheoums5)25eyamsy,,bheqlomemlicdcredalommictengsedrig.nuwsalid;afee;erjpeeoneeaeerate:eelietolaae.abaneaovineies2)@maadhaarqaweremuwuuwetuosshe.miaenpaneetereerenteaeaoncuneosreagsgieqecogytuscnpomaisls5typay:;pyarerey,sadherons;:baieeenengsbss)=aadhaarisvalidthroughoutthecountry.clrelgsotganeposyeess:#aadhaarhelpsyouavailvariousgovernmentnaltiiehssilhismetssighaucerep,andnon-governmentserviceseasily.rear;=keepyourmobilenumber&emailidupdated|2fisemtbhetedor/youraadhaarno.:inaadhaar.845095924360.=carryaadhaarinyoursmartphone—usensneaaodaceebonn‘mmmeyncaaicacatteeyueofticaleweiig™uw6t6tiad)lah,e1601)61usireetildteterenrneennneeneeennee=|fe-oooeeeeeeeeeeeeeeee+++--+e-pdgovernmentofindiaennccuniqueidentificationauthorityofindiatn£reer|ee+opn,ax’.sd-26aepeetami4grtwsitl‘ivtwette,61-36,mog,7goro,auciwd-26,baryrenisesemeie=seeanuthigsharangaraj,§puteaped,@pherdaungsrguesn,86hetae::aspgsper/dob:10/11/2003‘isbippat-601803pcachatipiers5=queisr/femalewereeteuae:°*a‘|saddress:guighaechmaanats);ee<4:|sd/orangaraj,c-36,mysoreroad,block-extnt@sevarsharatanceé£=,1326:itownship,kurinjipaditaluk,piaceeaxseverpine;,cuddalore,ttaareaes,:|=tamilnadu-607803avndeecubk:‘mamare9,olpeerade)ailsvatevalhn845095924360845095924360vid:9132479567¥vid:9136780612479567—~wwowsweerer<tentsrt|miamilljit6ytld-g@1047|4help@uidaigovin|gdwww.uidai.gov.in
# anuthigsha
# rangaraj
# 29
# tamilnadu
# [] NAME_LIS
# [['block', 'block']] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# mysore road block kurinjipadi neyveli cuddalore
# doc_info:---->
#   [{'DOC_TYPE': 'AADHAAR', 'Masked_Adhaar_No': 'XXXXXXXX4360', 'Ap_Full_Name': ' anuthigsha rangaraj', 'Ap_DOB': '10/11/2003', 'Res_Address': 'mysore road block kurinjipadi neyveli cuddalore', 'Res_pin': '607803', 'Res_State': 'TAMILNADU', 'raw_text': 'eeetopditenweaeertutaeeaadhaarophhwsbtsfimmiswpecroyeelantsiayeemialeireoatiattedmsoseolwntsepnhsnensnsigygqupmwsssisdovsmueeitsosuwetugshsimlwrmgengseflunpsacydopssonisolwineblenrsworsssoloolitogiqedrralé...é1326itownshipkurinjipaditalukpiaceeaxseverpinecuddalorettaareaestamilnadu607803avndeecubkmamare9olpeeradeailsvatevalhn845095924360845095924360vid9132479567vid9136780612479567wwowsweerertentsrtmiamilljit6ytldg10474helpuidaigovingdwwwuidaigovin'}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 1, 'Ap_Full_Name_percentage': 100.0, 'Ap_DOB_percentage': 100, 'Res_Address_Percentage': 77.04918032786885, 'Res_pin_Percentage': 100, 'Res_State_Percentage': 100, 'DOC_1_PERCENTAGE': 92.34972677595628}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 92.34972677595628, 'AADHAAR DOC PERCENTAGE IS MORE THAN 70%', {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': '', 'Masked_Adhaar_No': '', 'PAN_no': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': '', 'Ap_DOB_percentage': '', 'Res_Address_Percentage': '', 'Res_pin_Percentage': '', 'Res_State_Percentage': '', 'Masked_Adhaar_No_Percent': '', 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '1' , O_PAN_MATCHED = '' ,
#     O_DOC_1="eeetopditenweaeertutaeeaadhaarophhwsbtsfimmiswpecroyeelantsiayeemialeireoatiattedmsoseolwntsepnhsnensnsigygqupmwsssisdovsmueeitsosuwetugshsimlwrmgengseflunpsacydopssonisolwineblenrsworsssoloolitogiqedrralé...é1326itownshipkurinjipaditalukpiaceeaxseverpinecuddalorettaareaestamilnadu607803avndeecubkmamare9olpeeradeailsvatevalhn845095924360845095924360vid9132479567vid9136780612479567wwowsweerertentsrtmiamilljit6ytldg10474helpuidaigovingdwwwuidaigovin", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="",
#         O_PERCENT_DOC1_MATCHED= '92.34972677595628' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0',
#         O_MATCH_STATUS = 'VALID', O_PERCENT_PDF_MATCHED ="92.34972677595628",
#
#         O_FULL_NAME_MATCHED_DOC1 = ' anuthigsha rangaraj,100.0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = ',',
#
#         O_DOB_MATCHED_DOC1 = '10/11/2003,100', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = ',',
#
#         O_ADDRESS_MATCHED_DOC1 = 'mysore road block kurinjipadi neyveli cuddalore,77.04918032786885', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',',
#         O_STATE_MATCHED_DOC1 = 'TAMILNADU,100', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = ',',
#
#         O_PINCODE_MATCHED_DOC1 = '607803,100', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = ',',
#
#
#         O_REMARK='AADHAAR DOC PERCENTAGE IS MORE THAN 70%', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243588154'
# MySQL connection is closed
# MySQL connection_performance is closed
# -881037243588261
# 5848 4132
# -881037243577061
# -881037243595364
# 5848 4132
# 5848 4132
# RAW text---->
# [] NAME_LIS
#
# [] NAME_LIS
#
# [] NAME_LIS
#
# 31
# uttar pradesh
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
#
# 5848 4132
# -881037243584116
# 5848 4132
# RAW text----> =~i=1424/13...=:eonsemiseyeswejetssermoeeavatrtdee;iehomefo613129160416613129160416esiec|oe
# [] NAME_LIS
#
# [] NAME_LIS
#
# [] NAME_LIS
#
# 31
# uttar pradesh
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
#
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 0.0, '', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': '   ', 'Ap_DOB': 'nan', 'Res_Address': '', 'Res_pin': 'nan', 'Res_State': 'nan', 'raw_text': 'i142413eonsemiseyeswejetssermoeeavatrtdeeiehomefo613129160416613129160416esiecoe', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'Not Found'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0.0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0.0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0.0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="i142413eonsemiseyeswejetssermoeeavatrtdeeiehomefo613129160416613129160416esiecoe",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0.0',
#         O_MATCH_STATUS = 'MANUALLY CHECK', O_PERCENT_PDF_MATCHED ="0.0",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = '   ,0.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = 'nan,0',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',0.0',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'nan,0',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = 'nan,0',
#
#
#         O_REMARK='', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243588261'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> jesas.~onaa~~4t}“governmentofindiasitetlelxais—_adavaluram5dayaluram$wtfafs/dob:20/10/1979g—qes/male%)ryoeé33jp8ulbez:800264334559vid:9179720675659735art31remm,aygedietgras—pagsuiquelicentifcatiomautnorityofmdia~“anyaadhaartel:.dalpgaeanbateeeot]s/owide,var,as,fnsyedsean!eternfearaciweet-176121aeoe=address:belneurcenrae«1s/opuranchand,shakrog(531),mandi,akeieeepeat@himachalpradesh-176121ieitesatay6sysuereneseeaeranaea=poetyhensmenareatienzfeeretees:sae6ruaiagesmeeeapatitedaemereotccetakeooest_,800264334559vid:9179720675659735sx1947|bxjhelp@uidai.gov.in|a2e>)www.uidai.gov.in|
# ram
# ...
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="ieitiysoneganhsiinealn3hiurigsfeohaayfreeeal7yeegiatatemaekeeoeaeehieayeseeteeytear4i7iofnaoofyaraimgzfpaar4anat3tiialkialaa5odseadaa",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '1.3071895424836601',
#         O_MATCH_STATUS = 'MANUALLY CHECK', O_PERCENT_PDF_MATCHED ="1.3071895424836601",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = '  ,0.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = 'nan,0',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = 'so,3.9215686274509802',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'nan,0',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = 'nan,0',
#
#
#         O_REMARK='', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243588585'
# MySQL connection is closed
# MySQL connection_performance is closed
# -881037243584175
# 5848 4132
# -881037243588666
# RAW text----> fous)que||i=yeteeph,01908-25020|savingsbankaccodlgdtateedep@sbkatipartatebankofindiaie.cifno:81303879754.ekatipari_«aceountno:11589843596customername:dayaluram_—-.;:$/d/w/h/oo:puranchandaaddress:vill.sakrog,popadhar,phone:2602017‘tehpadhar.email:sbi.o9987@sbi.co.in,|disttmandi’’*hpbranchcode:9987|phpne:001908260130ec‘--date-ofissue:18/06/20197email:18/06/2019.52979589987a:0.0.8.(ifminor}::ifsc:sbinooo9987(—mop.:singlemicr:176002191yirgtweteteh/#7nee)nom.reg.no.:0000000244510838continuationbranchmanagen(ory|enpataesan|loreansapo<4:ee|chequenodebitcredit_eae|dateparticularseteenac,icadaca||aeeeeetn-23a7ycapffe|ereeeeeeeeeoeeee4a253ac?i-gs.eesswe©groughtforward.3793.50€cr<)0°)sietvsrelssetselooe1.etspovy:;om‘at09987.katipari28:06:22apash550°scbmedicalcollege.001793.50cr03.07.22upi/or/218453805677/bharti4/yes8/ai-001492.50.05,.6926761620~.i;sow,:at09987katipart3°oofsig:©ee20500©flrbal:492.50cr;|bsr0.00;mkten-47.07.22°838719256/phonepe/yesb/billdes62.001430.50cri©qt099b7katipard=©=ers)|27.07.22upi/dr/220821587130/fancode/pytm/paytm-s99.001331.50cr695975162096e,“at09987katipariaaa8.01.22mplldb4c2s:ddpayyesb/0o2z092onahesek150000.~..+2-e.n=5fu“—=_&stser™ae=694134162090_at09987katipariunc]ba):0.00{cirbal:31.50cr;]#modbal:0.0011.08.22upi/cr/222341965761/sanjay/sbin/91.100.00131.50cr|693371162097atieoss.kine8.00ie31.‘ba-|aal—_——_oe—waathlelgatvar4fagen/incaseofanygrievance/feedback,youmaywrite/mailtotothegeneralmanager’/gsidwaefelipa(nbg-coordination)ehwaaaaasrafawaorawtara/statebankofindiapleasepastephotographrcustomerservicedepartmentdonotaicecigyifeeeoe:isaoao\|statebankbhavan,16thfloor[=[a*pnauingauthoritymadamcamaroad,mumbai-400021atefax:022-22742431snfe-mail:gm.caustomer@sbi.co.in~*amet/fartftfrarca/utafarn&ame4acapreafafadvaafera/aaae:‘qsley;wea‘(mediaafaraye-aa)wandatefawemharfart422smwar.16417tollfreecontactno.::°sreearmte,aé-4000211800112211,18004253800,ag:02222742431aewalahhi;——;¢-4a:gm.caustomer@sbi.co.in|1800112211,18004253800
# ram
# dayalu
# 13
# himachal pradesh
# [] NAME_LIS
# sakrog teh padhar padhar mandi
# 5848 4132
# 5848 4132
# -881037243577116
# 5848 4132
# RAW text----> asean/signa“permanentaccountnumber(pan)facilitateincometaxdepademandtaxarrears,matchingofinformationandeasymaintenanceqcsthe(ta)usseale4halafalaselaalhlsisa4hamsnsaeahhlasmvalea8geelblehiast¥quotingofpanisnowmandatoryforseveraltransactionsspecifiaaablan,1961&dadleeheced&hfeeeaceagst(¥__possessingorusingmorethanonepanisagainstthelaw&may:neeageeereenaeeeeeeuhsathcaelasisst(fa)htvstasvnsea,ha&faaz¥thepancardenclosedcontainsenhancedorcodewhichisreapponsooeplaystoreis“enhancedqrcodereaderforpandeadwaisfwasnlstn&alwesfalseweissrar“enhancedqrcodereaderforpancard"@|!esbxerasjaixcj|by‘a'!tortcreaetsbes!permanentaccountnumbercardspieserictas=2amaebe|eeleleaaraateisacsar!azmpa0427gbeaneeae|deeteasa:mohdhasanansarieiseee|ta]1athfather'snameaeufersgua}samiullahbakreedanansariijet|eeatarp|jpfase|dateofbith==v7|01/10/1993fettsignature"electronicallyissuedanddigitallysignedepanisavalidmodeofissue«explanationoccurringaftersub-section(8)ofsection139aofincometa:
# ansari
# [['ullah']] NAME_LIS
# ullah
# mohd hasan
# 19
# maharashtra
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# main
# [['azmpa0427g']] NAME_LIS
# azmpa0427g
# 5848 4132
# RAW text----> :-amy'®j"rlii4—"“ihit5!=ayl.>‘i4p7.®s"a-2-—”épy2*rd_izs_4-i'—,ilaais
# [] NAME_LIS
#
# [] NAME_LIS
#
# 13
# himachal pradesh
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
#
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 0.0, '', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': '  ', 'Ap_DOB': 'nan', 'Res_Address': '', 'Res_pin': 'nan', 'Res_State': 'nan', 'raw_text': 'amyjrlii4ihit5ayli4p7sa2épy2rdizs4iilaais', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'Not Found'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0.0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0.0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 0.0}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="amyjrlii4ihit5ayli4p7sa2épy2rdizs4iilaais",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '0.0',
#         O_MATCH_STATUS = 'MANUALLY CHECK', O_PERCENT_PDF_MATCHED ="0.0",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = '  ,0.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = 'nan,0',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = ',0.0',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'nan,0',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = 'nan,0',
#
#
#         O_REMARK='', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243595364'
# MySQL connection is closed
# MySQL connection_performance is closed
# RAW text----> a;y’ny‘\le,ln.-===—awah).1see|aa*aqlhyiiyistottur*lik._apoe:i7’i;,|.*saell|i4\*’7_:-_—til;fae‘a74j-”ia"f,*7'ooij®ft.~.4—_—s;kei=='!=.¥‘~-s=mo~besisicicisreyae=bimhisis7saoei|nbseinsoozis3nmasaeirisise:.2~aefieieeeeesee55|nm5,«ftsnf¢sgoaat—_—z“4wa;gtooa:=34—=a2“744oa>°-,§>7}“na|wasa¥ner!~.7.ooaeico|na>®:=©le)a©aeaaanmann——nenmaad7>=3weuia~s7==|eeo~
# [] NAME_LIS
#
# [] NAME_LIS
#
# 36
# telangana
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
#
# RAW text----> \geo\:rtosaenreaeeeeee————oearaaeydlstee:pyaeete="éeencathwiceoqcya‘onearesaeeeeeetmaea=ra850929ze16028509l9ze1604sooees-usapeiyesypuysookes-apbomeae‘uearpod[eey'(uequr)bpoumeymecoumwe‘ehbepapewownimy™20iwburddousls"dorcgrotorgegegascawwwas/&,agw1fgio“cwoando109vwhoownaydvét,es)iistereety-2“posiuggipuiaeypuayuegomiaegueygaed=ersserippyfitoc,=seaippya=pcobceanoc:———_——»-—bipupjojubwiweaddfa:~2:||ql0ocy)o&‘oudea:“onjeeupeyyuno,/scoreoutacecanes,“qin}nyulsaowaesjuswwlubaos)-uon)pur——ml°juewlueaosbhuieakuljnydjayaqjiimweeypeywpure&-aayunooayyjnoybnosuypijeasiseeypeywdeutchceooe§"qoorcis(sheoptopootracy(uuequm)epeuimey:opsaq2@croecesemacsleceo.an«s010weybuiddoys1ywhseusddg©vovnimw|“goitersporesgor&|gvohano109whoownnwdvd&-_|feeaganaengtetreesoebyaratpreeeeeeabel-onovou'yvdvnwaywmhsi'9e/cer-zsseejeverpereovesaeouorpap9a=sapnon“@uuo@jed)]uayne‘ajuap!ysiqe}seo|&ia5‘diysuaziyojojou‘ayuep!jooodesljeeeyupeyy&oo}enoilwwyosni5;a‘apepamedesschoroe:s9clp/9zooo/zes1“onjuouuasckeencaemegoi.cgeggonegageapsgtytehqwdie‘sepsurrassseseeoonwoesaee=3'eu=fileeee:wwe=|ie*|--rrzzwsv~eos
# [] NAME_LIS
#
# [] NAME_LIS
#
# 2
# andhra pradesh
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# [] NAME_LIS
# no 1
# doc_info:---->
#   [{'DOC_TYPE': '', 'Masked_Adhaar_No': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Masked_Adhaar_No_Percent': 0, 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_1_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_2_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_3_PERCENTAGE': 0}, {'DOC_TYPE': '', 'Ap_Full_Name': '', 'Ap_DOB': '', 'Res_Address': '', 'Res_pin': '', 'Res_State': '', 'raw_text': ''}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0, 'Ap_DOB_percentage': '', 'Res_Address_Percentage': 0, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'DOC_4_PERCENTAGE': 0}, {'DOC_TYPE': '', 'raw_text': ''}, {'DOC_TYPE': '', 'PAN_match_percentage': ''}, 2.4691358024691357, '', {'DOC_TYPE': 'OTHER', 'Ap_Full_Name': '  ', 'Ap_DOB': 'nan', 'Res_Address': 'no 1', 'Res_pin': 'nan', 'Res_State': 'nan', 'raw_text': 'geortosaenreaeeeeeeoearaaeydlsteepyaeeteéeencathwiceoqcyaonearesaeeeeeetmaeara850929ze16028509l9ze1604sooeesusapeiyesypuysookesapbomeaeuearpodeeyuequrbpoumeymecoumweehbepapewownimy20iwburddouslsdorcgrotorgegegascawwwasagw1fgiocwoando109vwhoownaydvé...', 'Masked_Adhaar_No': 'nan', 'PAN_no': '', 'PAN_no_match': 'Not Found'}, {'DOC_TYPE': '', 'Ap_Full_Name_percentage': 0.0, 'Ap_DOB_percentage': 0, 'Res_Address_Percentage': 7.4074074074074066, 'Res_pin_Percentage': 0, 'Res_State_Percentage': 0, 'Masked_Adhaar_No_Percent': 0, 'PAN_match_percentage': '', 'DOC_6_PERCENTAGE': 2.4691358024691357}]
# UPDATE PAN_CUSTOMER_DATA1 SET   O_ADHAAR_NO_MATCHED = '0' , O_PAN_MATCHED = '' ,
#     O_DOC_1="", O_DOC_2="", O_DOC_3="", O_DOC_4="", O_DOC_5="",  O_DOC_6="geortosaenreaeeeeeeoearaaeydlsteepyaeeteéeencathwiceoqcyaonearesaeeeeeetmaeara850929ze16028509l9ze1604sooeesusapeiyesypuysookesapbomeaeuearpodeeyuequrbpoumeymecoumweehbepapewownimy20iwburddouslsdorcgrotorgegegascawwwasagw1fgiocwoando109vwhoownaydvé...",
#         O_PERCENT_DOC1_MATCHED= '0' , O_PERCENT_DOC2_MATCHED= '0' , O_PERCENT_DOC3_MATCHED= '0', O_PERCENT_DOC4_MATCHED= '0',  O_PERCENT_DOC6_MATCHED= '2.4691358024691357',
#         O_MATCH_STATUS = 'MANUALLY CHECK', O_PERCENT_PDF_MATCHED ="2.4691358024691357",
#
#         O_FULL_NAME_MATCHED_DOC1 = ',0', O_FULL_NAME_MATCHED_DOC2 = ',0', O_FULL_NAME_MATCHED_DOC3 = ',0', O_FULL_NAME_MATCHED_DOC4 = ',0',  O_FULL_NAME_MATCHED_DOC6 = '  ,0.0',
#
#         O_DOB_MATCHED_DOC1 = ',0', O_DOB_MATCHED_DOC2 = ',', O_DOB_MATCHED_DOC3 = ',', O_DOB_MATCHED_DOC4 = ',',O_DOB_MATCHED_DOC6 = 'nan,0',
#
#         O_ADDRESS_MATCHED_DOC1 = ',0', O_ADDRESS_MATCHED_DOC2 = ',0', O_ADDRESS_MATCHED_DOC3 = ',0', O_ADDRESS_MATCHED_DOC4 = ',0',O_ADDRESS_MATCHED_DOC6 = 'no 1,7.4074074074074066',
#         O_STATE_MATCHED_DOC1 = ',0', O_STATE_MATCHED_DOC2 = ',0', O_STATE_MATCHED_DOC3 = ',0', O_STATE_MATCHED_DOC4 = ',0', O_STATE_MATCHED_DOC6 = 'nan,0',
#
#         O_PINCODE_MATCHED_DOC1 = ',0', O_PINCODE_MATCHED_DOC2 = ',0', O_PINCODE_MATCHED_DOC3 = ',0', O_PINCODE_MATCHED_DOC4 = ',0', O_PINCODE_MATCHED_DOC6 = 'nan,0',
#
#
#         O_REMARK='', O_PROC_FLAG=1,  O_LUPD_DATE =now()
#                              WHERE
#                              P_BATCH_ID='ca7756c2c9384a968db59faf421f1f2e' and P_ACK_NO='881037243588666'
# MySQL connection is closed
# 5848 4132
# MySQL connection_performance is closed
